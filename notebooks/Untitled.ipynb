# %%
# Developing the Python script to obtain 50 random zip codes.

# %%
# Import libraries.
import pandas as pd
from select_zips import random_zips
from yelpapi import YelpAPI

# %%
# The list of Wisconsin Zip codes is provided here
wi_zip_codes = pd.read_csv('../data/WIzips.csv').iloc[:,0].tolist()

# %%
key = 'jWpt3Tqvtyrq1y-0WjHcYZQ_JhUMT1Wqlhh8LQ_duNhO-w8urh6JfbyQ-7WIMK3Bkxd88APZE8v6urU22KO5GRlajmHtG-PM9SvtZNekJ5z_yKpHF8lvsR_kmQotXHYx'

# %%
yelp = YelpAPI(key)

# %%
n_zips = 50

# %%
# Casting the data type of the DataFrame into strings
list_of_zips = [str(i) for i in wi_zip_codes]

# %%
# Creating a Series from the inputted list of zip codes
zip_list = pd.Series(list_of_zips)

# %%
# Creating an empty list of the number of businesses in a zip code
zip_bus_list = []

# %%
for zipcode in zip_list:
    # Using exceptions in case Yelp APIs restrictions are met
    try: 
        # Using the Yelp API search query to retrieve 1 business per zip code
        search = yelp.search_query(location=zipcode, limit=1)
        
        # Appending to the list search['total'], which is the total number
        # of businesses in a zip code (this metadata is available with each inidividual
        # business search call)
        zip_bus_list.append(search['total'])
    except:
        pass
# Out:
# 192
# 4
# 108
# 2800
# 14
# 87
# 34
# 45
# 528
# 60
# 22
# 18
# 1
# 545
# 506
# 164
# 51
# 202
# 657
# 93
# 328
# 77
# 245
# 1
# 94
# 379
# 94
# 93
# 243
# 455
# 160
# 62
# 72
# 20
# 215
# 1600
# 51
# 47
# 53
# 159
# 39
# 1600
# 110
# 492
# 140
# 73
# 15
# 168
# 144
# 48
# 258
# 466
# 70
# 199
# 28
# 354
# 63
# 23
# 263
# 243
# 255
# 241
# 302
# 3
# 857
# 121
# 66
# 740
# 132
# 91
# 132
# 703
# 75
# 718
# 669
# 92
# 842
# 178
# 177
# 140
# 277
# 130
# 78
# 133
# 238
# 94
# 155
# 361
# 809
# 173
# 1700
# 200
# 222
# 612
# 650
# 290
# 708
# 1500
# 199
# 130
# 1100
# 2600
# 51
# 1400
# 109
# 663
# 7
# 343
# 26
# 103
# 654
# 179
# 573
# 469
# 56
# 99
# 305
# 287
# 1300
# 785
# 313
# 58
# 37
# 20
# 825
# 945
# 919
# 898
# 656
# 2400
# 498
# 2200
# 1700
# 1200
# 1400
# 1600
# 2800
# 1900
# 1500
# 2000
# 914
# 1800
# 1200
# 1000
# 799
# 394
# 359
# 547
# 949
# 257
# 856
# 983
# 272
# 499
# 608
# 267
# 492
# 532
# 3
# 126
# 77
# 8
# 277
# 6
# 17
# 41
# 71
# 160
# 87
# 12
# 39
# 6
# 22
# 63
# 61
# 178
# 306
# 5
# 289
# 202
# 86
# 11
# 241
# 191
# 25
# 68
# 19
# 1
# 114
# 12
# 5
# 46
# 221
# 180
# 151
# 85
# 79
# 73
# 1
# 4
# 48
# 55
# 8
# 1100
# 62
# 48
# 87
# 1200
# 129
# 18
# 46
# 6
# 30
# 1
# 37
# 5
# 53
# 1000
# 156
# 7
# 30
# 18
# 58
# 24
# 53
# 37
# 197
# 22
# 13
# 31
# 90
# 260
# 327
# 41
# 361
# 145
# 603
# 1500
# 946
# 572
# 1400
# 1500
# 832
# 600
# 824
# 417
# 918
# 705
# 222
# 15
# 83
# 3
# 12
# 5
# 16
# 2
# 12
# 20
# 33
# 12
# 26
# 39
# 10
# 45
# 29
# 4
# 11
# 60
# 25
# 173
# 146
# 56
# 4
# 5
# 113
# 3
# 4
# 27
# 32
# 4
# 52
# 77
# 46
# 41
# 29
# 4
# 19
# 5
# 38
# 23
# 9
# 164
# 11
# 29
# 19
# 29
# 52
# 14
# 1
# 25
# 39
# 17
# 31
# 8
# 187
# 19
# 12
# 125
# 19
# 1
# 17
# 26
# 15
# 11
# 14
# 29
# 5
# 51
# 15
# 6
# 82
# 32
# 218
# 42
# 25
# 64
# 46
# 171
# 26
# 123
# 81
# 34
# 23
# 353
# 22
# 5
# 3
# 6
# 32
# 23
# 27
# 25
# 11
# 113
# 33
# 329
# 2
# 1
# 10
# 2
# 15
# 4
# 14
# 8
# 38
# 177
# 4
# 123
# 53
# 19
# 23
# 325
# 9
# 88
# 24
# 2
# 71
# 24
# 17
# 520
# 6
# 26
# 4
# 1
# 15
# 16
# 29
# 50
# 55
# 12
# 64
# 349
# 9
# 23
# 7
# 45
# 23
# 92
# 36
# 24
# 18
# 113
# 112
# 76
# 112
# 23
# 2
# 21
# 27
# 123
# 39
# 63
# 286
# 25
# 1
# 133
# 70
# 46
# 57
# 41
# 148
# 578
# 417
# 586
# 478
# 2
# 277
# 441
# 201
# 92
# 19
# 86
# 49
# 3
# 31
# 6
# 6
# 5
# 4
# 3
# 10
# 3
# 4
# 18
# 19
# 60
# 4
# 17
# 5
# 17
# 10
# 2
# 3
# 6
# 3
# 7
# 75
# 11
# 12
# 1
# 20
# 16
# 66
# 20
# 20
# 33
# 3
# 22
# 17
# 22
# 4
# 6
# 11
# 9
# 14
# 1
# 132
# 8
# 5
# 126
# 6
# 104
# 114
# 198
# 10
# 33
# 165
# 167
# 9
# 12
# 8
# 34
# 11
# 77
# 2
# 10
# 1
# 75
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-9-49dbf0a14614> in <module>
#       1 for zipcode in zip_list:
#       2     # Using the Yelp API search query to retrieve 1 business per zip code
# ----> 3     search = yelp.search_query(location=zipcode, limit=1)
#       4     print(search['total'])
#       5     # Appending to the list search['total'], which is the total number
#
# /anaconda3/lib/python3.6/site-packages/yelpapi/yelpapi.py in search_query(self, **kwargs)
#     230                              '(parameters "latitude" and "longitude") must be provided.')
#     231
# --> 232         return self._query(SEARCH_API_URL, **kwargs)
#     233
#     234     def transaction_search_query(self, transaction_type, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/yelpapi/yelpapi.py in _query(self, url, **kwargs)
#     272             timeout=self._timeout_s,
#     273         )
# --> 274         response_json = response.json()  # shouldn't happen, but this will raise a ValueError if the response isn't JSON
#     275
#     276         # Yelp can return one of many different API errors, so check for one of them.
#
# /anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     894                     # used.
#     895                     pass
# --> 896         return complexjson.loads(self.text, **kwargs)
#     897
#     898     @property
#
# /anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Converting the list of businesses into a Series, and then into a DataFrame
# that includes the zip code and number of businesses
zip_bus_list_series = pd.Series(zip_bus_list)
df_business = pd.concat([zip_list, zip_bus_list_series], axis=1)

# %%
# Renaming the appended columns to 'zipcode' and 'n_business'
df_business = df_business.rename(columns= {0 : 'zipcode',
                                           1 : 'n_business'})

# %%
# Only choosing zip codes that have between 50 and 1000 businesses
df_avail = df_business[(df_business['n_business'] < 1000) & (df_business['n_business'] > 50)]

# %%
# Setting a random seed for reproducibility
np.random.seed(42)

# %%
# Choosing n_zips specified amount of
# random zipcodes from the available list
if(n_zips > df_avail.shape[0]):
    print('You specified more zipcodes than are available in your list')
    n_zips = df_avail.shape[0]

# %%
zip_list = np.random.choice(df_avail['zipcode'], n_zips, replace=False)

# %%
zip_list
# Out:
# array(['54406', '53125', '53021', '54220', '53032', '54210', '53046',
#        '54171', '53705', '53527', '54313', '53036', '53203', '54016',
#        '54474', '53550', '53582', '53059', '54476', '54115', '53228',
#        '53726', '54423', '54025', '53525', '53035', '53585', '53218',
#        '53224', '53177', '54202', '53115', '53505', '53089', '53033',
#        '53528', '53717', '53510', '53168', '53576', '53189', '53922',
#        '53574', '53140', '53404', '53403', '53593', '53104', '53911',
#        '53129'], dtype=object)
